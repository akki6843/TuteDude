# %% [markdown]
# # Assignment 1 : Data Structures

# %% [markdown]
# Previous Submission failed because mentor thought I have used AI to solve the problem.

# %% [markdown]
# Mentor Feedback for previous submissions:
# Your code is functionally correct for most tasks and shows you understand the core concepts of Python data structures. However, I need to be direct: this submission shows strong indicators of AI assistance, particularly the overly polished structure, perfect completion of all optional tasks without any incomplete attempts or corrections, and the 'GEN-AI by TuteDude' header. This is not acceptable for learning. You need to rework this assignment yourself to demonstrate genuine understanding. Start by rewriting Task 4.1 to fix the catalog creation logic, remove all template headers, and add your own comments explaining your thinking. This will help you actually learn these concepts rather than just having working code.
#
# Requirements Missing:
#
# Task 4.1: Catalog creation has flawed logic - doesn't properly match all products with their correct categories
# Task 4.1: Catalog should use both products list and price_dict more explicitly
# README.md file explaining which file runs which task (optional but missing)
# Clear evidence of student's own work - submission shows AI assistance indicators

# %% [markdown]
# ---

# %% [markdown]
# **NOTE**: I use intellisense and for auto-complete which is a NON-AI setup (as per my knowledge) and use wisper-flow speech to text model for documentation, so that I do not have to type the documentation. These extensions save a lot of time and looks good. All the code written is purely from my own though and no cheating or funky business. Also I have been coding for sometime so may be because of old documenting habit caused to much of comments. So I will be removing them. And since task 4 was not done properly little more explanation added there. And notebook should cover readme requirment also.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# Task 1 : Product collections (lists and tuples)
# 1: Create a list named products containing at least six product names, all in strings.
# 2: Create a tuple named sample_product that stores product name, price, and category for one product.
# 3: Print the second and the last product from the product list.
# 4: Append two new product names to products and then print the updated list.
# Extra (Optional): Convert sample product into a list, change its price, and convert it back to a tuple

# %%
products = ["Laptop", "T-shirt", "Readers-digest", "Lamp", "Basketball", "Hotweels"]



sample_product = ("Laptop", 999.99, "Electronics")



print("Second product:", products[1])

print("Last product:", products[-1])



products.append("Tablet")

products.append("Smartwatch")

print("Updated product list:", products)



sample_product_list = list(sample_product)

sample_product_list[1] = 899.99  # Change price

sample_product = tuple(sample_product_list)



print("Updated sample product:", sample_product)
# Out:
# Second product: T-shirt
# Last product: Hotweels
# Updated product list: ['Laptop', 'T-shirt', 'Readers-digest', 'Lamp', 'Basketball', 'Hotweels', 'Tablet', 'Smartwatch']
# Updated sample product: ('Laptop', 899.99, 'Electronics')

# %% [markdown]
# Explanation :
# Created a Product list.
# created a sample product, showing product price and category.
# Task specified list manipulation such as slicing, appending and index based update.

# %% [markdown]
# ---

# %% [markdown]
# Task 2 : Categories(Sets)
# 1: From your product list, create a set of categories called categories_set (If product name does not contain categories, create a short parallel list categories=[...] With matching length and use that. )
# 2: Demonstrate adding a new category to the set and show that duplicates are ignored.
# 3: Show how to check whether a category exists in the set(Print a Boolean result).
# Extra(Optional) : Show how to get the total number of unique categories using a set.

# %%
categories = ["Electronics", "Clothing", "Books", "Home", "Sports", "Toys"]

categories_set = set(categories)



categories_set.add("Gaming")

print("Categories after adding 'Gaming':", categories_set)



print("Does 'Electronics' exist in categories_set?", "Electronics" in categories_set)



print("Total number of unique categories:", len(categories_set))
# Out:
# Categories after adding 'Gaming': {'Gaming', 'Electronics', 'Toys', 'Books', 'Sports', 'Clothing', 'Home'}
# Does 'Electronics' exist in categories_set? True
# Total number of unique categories: 7

# %% [markdown]
# Explanation :
# Working with sets. Since my list is all unique there is no change after applying set.
# Few tasks on playing with set. Essentially set object element also works similar to list so not much to say.

# %% [markdown]
# ---

# %% [markdown]
# Task 3 : Product Pricing (Dictionaries):
#
# 1: Create a dictionary price_dict where keys are product names and values are prices(Integers or floats). Include at least six entries.
#
# 2: Write small code blocks to:
#
# - Update the price of the existing product.
#
# - Remove a product by name(Handle the case when the product does not exist.)
#
# 3: Print the average price of all products (Use only dictionary operations and basic arithmetic.)
#
# Extra(Optional) : Print the product with both the maximum and minimum prices.

# %%
price_dict = {

    "Laptop": 999.99,

    "T-shirt": 699.99,

    "Readers-digest": 199.99,

    "Lamp": 299.99,

    "Basketball": 79.99,

    "Hotweels": 29.99,

    }



price_dict["Laptop"] = 899.99

print("Updated price of Laptop:", price_dict["Laptop"])



product_to_remove = "Tablet"

if product_to_remove in price_dict:

    del price_dict[product_to_remove]

    print(f"Product '{product_to_remove}' removed.")

else:

    print(f"Product '{product_to_remove}' not found.")



total_price = sum(price_dict.values())

average_price = total_price / len(price_dict)

print("Average price of all products:", average_price)



max_product = max(price_dict, key=price_dict.get)

min_product = min(price_dict, key=price_dict.get)

print("Product with maximum price:", max_product, "->", price_dict[max_product])

print("Product with minimum price:", min_product, "->", price_dict[min_product])
# Out:
# Updated price of Laptop: 899.99
# Product 'Tablet' not found.
# Average price of all products: 368.3233333333333
# Product with maximum price: Laptop -> 899.99
# Product with minimum price: Hotweels -> 29.99

# %% [markdown]
# Explanation :
# Same like before showing how to play with dictonary.
# basically CRUD operations for the dict object.

# %% [markdown]
# ---

# %% [markdown]
# Task 4 : Combined operations
# 1: Using the products list and price_dict, create a list of tuples named catalog where each tuple is (product name, price, category).
# 2: From catalog, create a new dictionary category_2_products that maps each category to a list of product names in that category.
# 3: Print all products that belong to the category that has the maximum number of products.

# %%
catalog = [(product, price_dict.get(product, None), category)

           for product, category in zip(products, categories)]



print("Catalog:", catalog)
# Out:
# Catalog: [('Laptop', 899.99, 'Electronics'), ('T-shirt', 699.99, 'Clothing'), ('Readers-digest', 199.99, 'Books'), ('Lamp', 299.99, 'Home'), ('Basketball', 79.99, 'Sports'), ('Hotweels', 29.99, 'Toys')]

# %% [markdown]
# Explanation :
# Essentially using lists from previous tasks and creating catalog that looks   similar to sample product that was created in task 1.

# %%
category_2_products = {}

for product, price, category in catalog:

    if category not in category_2_products:

        category_2_products[category] = []

    category_2_products[category].append(product)



category_2_products
# Out:
# {'Electronics': ['Laptop'],
#  'Clothing': ['T-shirt'],
#  'Books': ['Readers-digest'],
#  'Home': ['Lamp'],
#  'Sports': ['Basketball'],
#  'Toys': ['Hotweels']}

# %% [markdown]
# Explanation :
# creating a map type object using dict where we know in each category which all products are present.
# Since in my list one category one product we have 1:1 kind of key value. If more products are present then it would have looked bit different.

# %%
max_category = max(category_2_products, key=lambda k: len(category_2_products[k]))

print(f"Products in the category with the most products ({max_category}):")

for product in category_2_products[max_category]:

    print(f"  - {product}")
# Out:
# Products in the category with the most products (Electronics):
#   - Laptop

# %% [markdown]
# Explanation :
# Here we just find which category has most number of products.
# As, we have one product per category, code will give the first element in the input list.
# In the code I used "key" parameter, same as looping through and keep updating the list when we find bigger len update the max_category.

# %% [markdown]
# ---
